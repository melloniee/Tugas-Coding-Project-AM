# %%
import numpy as np
# Transpose dari kolom (25,2,-3,-23)
Xt = np.array([[25], [2], [-3], [-23]])
print(f"Matriks XT adalah: \n{Xt}")
# Out:
# Matriks XT adalah:
# [[ 25]
#  [  2]
#  [ -3]
#  [-23]]

# %%
#Melakukan Transpose

Xt_t = XT.T
print(f"Matriks XT adalah: \n{Xt_t}")
# Out:
# Matriks XT adalah:
# [[ 25   2  -3 -23]]
