# %%
#1. buat matrix X berukuran 2x3 menggunakan numpy

import numpy as np

X = np.array([[3, 4, 2], [3, 9, 7]])
X
# Out:
# array([[3, 4, 2],
#        [3, 9, 7]])

# %%
#tampilkan ukuran dari matrix X
X.shape

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X

X[:,0]

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]

# %% [markdown]
# Pytorch

# %%
#2. buat matrix X berukuran 2x3 menggunakan PyTorch

import torch

X_pt = torch.tensor([[14, 12, 9], [10, 15, 18]])
X_pt
# Out:
# tensor([[14, 12,  9],
#         [10, 15, 18]])

# %%
#tampilkan ukuran dari matrix X

X_pt.shape
# Out:
# torch.Size([2, 3])

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X

X_pt[:,0]

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X

X_pt[1,:]

# %% [markdown]
# Tensorflow

# %%
#buat matrix X berukuran 2x3 menggunakan Transflow

import tensorflow as tf

X_tf = tf.Variable([[17, 20, 24], [31, 22, 26]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[17, 20, 24],
#        [31, 22, 26]], dtype=int32)>

# %%
#tampilkan ukuran dari matrix X

tf.shape(X_tf)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X

X_tf[:,0]

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X

X_tf[1,:]
